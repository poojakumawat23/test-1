# %% [markdown]
# <a href="https://colab.research.google.com/github/poojakumawat23/test-1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount=('/content/drive')

# %%
df=pd.read_excel('/content/colab.xlsx')

# %%
df.head()
# Out:
#     Employee_Name  Employee_ID   Job_Role  Phone_Number  \
# 0     Jane Miller         8797  Developer  3.801881e+09
# 1   Michael Brown         6540    Manager  7.904752e+09
# 2  Sarah Anderson         2353  Developer  9.463822e+09
# 3   Chris Johnson         6392   Engineer  8.727628e+09
# 4     Laura Smith         1653    Analyst  7.750284e+08
#
#                    Email_ID  Total_Work_Hour_per_Month  Salary_per_Month
# 0  emily.taylor@example.com                     9999.0               NaN
# 1       john.brown@test.net                      160.0           11200.0
# 2   sarah.wilson@sample.org                     9999.0           -5000.0
# 3     john.jones@sample.org                      160.0            8000.0
# 4     sarah.taylor@test.net                     9999.0               NaN

# %%
df.tail()
# Out:
#     Employee_Name  Employee_ID  Job_Role  Phone_Number  \
# 95    Emily Smith         5111         0  4.463884e+09
# 96   Sarah Wilson         7388  Engineer  7.455009e+09
# 97              0         3773   Manager  4.515526e+08
# 98    Sarah Smith         1442   Analyst  3.294945e+09
# 99  Michael Jones         3490   Analyst  9.425622e+09
#
#                         Email_ID  Total_Work_Hour_per_Month  Salary_per_Month  \
# 95          james.davis@test.net                      -10.0          100000.0
# 96      john.johnson@example.com                        0.0          100000.0
# 97       david.miller@sample.org                        0.0          100000.0
# 98  jessica.anderson@example.com                      -10.0           -5000.0
# 99        john.miller@sample.org                        0.0               0.0
#
#     Hourly_Wage:
# 95      -10000.0
# 96           0.0
# 97           0.0
# 98         500.0
# 99           0.0

# %%
duplicate_employees=df[df.duplicated(subset="Employee_ID",keep=False)]
print(duplicate_employees)
# Out:
#     Employee_Name  Employee_ID        Job_Role  Phone_Number  \
# 6   Michael Jones         3654         Manager  8.045243e+09
# 16    Laura Jones         5596         Analyst  6.650995e+09
# 50     John Jones         1442  Data Scientist  3.139018e+09
# 56            NaN         3654       Developer  5.844402e+09
# 72    Jane Wilson         5596         Manager  9.602139e+09
# 98    Sarah Smith         1442         Analyst  3.294945e+09
#
#                         Email_ID  Total_Work_Hour_per_Month  Salary_per_Month
# 6     laura.williams@example.com                      160.0           11200.0
# 16     john.williams@example.com                      200.0           10000.0
# 50     laura.williams@sample.org                      160.0            8000.0
# 56          laura.brown@test.net                      -10.0          100000.0
# 72          jane.miller@test.net                      200.0           12000.0
# ...

# %%
df1=df['Job_Role'].unique()
print(df1)
# Out:
# ['Developer' 'Manager' 'Engineer' 'Analyst' 'Data Scientist' nan]

# %%
print(df)
# Out:
#      Employee_Name  Employee_ID   Job_Role  Phone_Number  \
# 0      Jane Miller         8797  Developer  3.801881e+09
# 1    Michael Brown         6540    Manager  7.904752e+09
# 2   Sarah Anderson         2353  Developer  9.463822e+09
# 3    Chris Johnson         6392   Engineer  8.727628e+09
# 4      Laura Smith         1653    Analyst  7.750284e+08
# ..             ...          ...        ...           ...
# 95     Emily Smith         5111        NaN  4.463884e+09
# 96    Sarah Wilson         7388   Engineer  7.455009e+09
# 97             NaN         3773    Manager  4.515526e+08
# 98     Sarah Smith         1442    Analyst  3.294945e+09
# 99   Michael Jones         3490    Analyst  9.425622e+09
#
#                         Email_ID  Total_Work_Hour_per_Month  Salary_per_Month
# 0       emily.taylor@example.com                     9999.0               NaN
# 1            john.brown@test.net                      160.0           11200.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_Name              91 non-null     object
#  1   Employee_ID                100 non-null    int64
#  2   Job_Role                   90 non-null     object
#  3   Phone_Number               92 non-null     float64
#  4   Email_ID                   91 non-null     object
#  5   Total_Work_Hour_per_Month  77 non-null     float64
#  6   Salary_per_Month           80 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 5.6+ KB

# %%
df['Hourly_Wage:'] = df['Salary_per_Month'] / df['Total_Work_Hour_per_Month']
print(df)
# Out:
#      Employee_Name  Employee_ID   Job_Role  Phone_Number  \
# 0      Jane Miller         8797  Developer  3.801881e+09
# 1    Michael Brown         6540    Manager  7.904752e+09
# 2   Sarah Anderson         2353  Developer  9.463822e+09
# 3    Chris Johnson         6392   Engineer  8.727628e+09
# 4      Laura Smith         1653    Analyst  7.750284e+08
# ..             ...          ...        ...           ...
# 95     Emily Smith         5111        NaN  4.463884e+09
# 96    Sarah Wilson         7388   Engineer  7.455009e+09
# 97             NaN         3773    Manager  4.515526e+08
# 98     Sarah Smith         1442    Analyst  3.294945e+09
# 99   Michael Jones         3490    Analyst  9.425622e+09
#
#                         Email_ID  Total_Work_Hour_per_Month  Salary_per_Month  \
# 0       emily.taylor@example.com                     9999.0               NaN
# 1            john.brown@test.net                      160.0           11200.0
# ...

# %%
df.dropna()
# Out:
#        Employee_Name  Employee_ID        Job_Role  Phone_Number  \
# 1      Michael Brown         6540         Manager  7.904752e+09
# 2     Sarah Anderson         2353       Developer  9.463822e+09
# 3      Chris Johnson         6392        Engineer  8.727628e+09
# 6      Michael Jones         3654         Manager  8.045243e+09
# 7        Sarah Smith         8297  Data Scientist  7.301689e+09
# 14    Michael Miller         1634  Data Scientist  2.416309e+09
# 15     Michael Smith         5621        Engineer  5.734920e+09
# 16       Laura Jones         5596         Analyst  6.650995e+09
# 18        John Smith         2486         Manager  5.180124e+09
# 29     Laura Johnson         8972  Data Scientist  3.477954e+09
# 31  Jessica Williams         9193  Data Scientist  8.414400e+09
# 36      James Miller         1613         Manager  2.074013e+09
# 38      Emily Wilson         9713         Manager  7.156704e+09
# 39    Jessica Miller         8776        Engineer  3.914933e+09
# ...

# %%
df.fillna(value=0,inplace=True)
print(df)
# Out:
#      Employee_Name  Employee_ID   Job_Role  Phone_Number  \
# 0      Jane Miller         8797  Developer  3.801881e+09
# 1    Michael Brown         6540    Manager  7.904752e+09
# 2   Sarah Anderson         2353  Developer  9.463822e+09
# 3    Chris Johnson         6392   Engineer  8.727628e+09
# 4      Laura Smith         1653    Analyst  7.750284e+08
# ..             ...          ...        ...           ...
# 95     Emily Smith         5111          0  4.463884e+09
# 96    Sarah Wilson         7388   Engineer  7.455009e+09
# 97               0         3773    Manager  4.515526e+08
# 98     Sarah Smith         1442    Analyst  3.294945e+09
# 99   Michael Jones         3490    Analyst  9.425622e+09
#
#                         Email_ID  Total_Work_Hour_per_Month  Salary_per_Month  \
# 0       emily.taylor@example.com                     9999.0               0.0
# 1            john.brown@test.net                      160.0           11200.0
# ...
